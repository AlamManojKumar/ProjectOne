# %%
Principal = 100000
Rate = 10
Time = 5
TotalAmount = Principal *(1+Rate/100)**Time
#Total Amount.
print("The amount is",TotalAmount)
#Compound Intrest.
compoundIntrest = TotalAmount-Principal
print("The compound intrest is",compoundIntrest)
# Out:
# The amount is 161051.00000000006
# The compound intrest is 61051.00000000006

# %%
a = "Manoj"
print(a)
# Out:
# Manoj

# %%
# How to reverse the word without using string reverse.
n = "mahesh"
li = n.split(" ")
for i in range (len(li)):
     print(li[i][::-1],end= " ")
# Out:
# hseham

# %%
# How to reverse the string with out using reverse function.
n = "Quality Taught"
li = n.split(" ")
print(li)
for i in range(len(li)):
    print(li[i][::-1],end= " ")
# Out:
# ['Quality', 'Taught']
# ytilauQ thguaT

# %%
# How to reverse the string with out using reverse function
n= "Teks Academy"
li = n.split(" ")
print(li)
for i in range(len(li)):
  print(li[i][::-1],end= " ")
# Out:
# ['Teks', 'Academy']
# skeT ymedacA

# %%
number =151
reverse =0
temp =number
while number >0:
   remainder = number % 10 
   reverse = (reverse *10)+ remainder
   number = number//10 
if temp == reverse:
   print("The number is palingdrome:")
else:
   print("The number is not palingdrome:")
# Out:
# The number is palingdrome:

# %%
# How to print the largest number in given list
numbers =[100,200,300,400,500]
largest = numbers[0]
for num in numbers:
    if num > largest:
        largest = num
print("largest number is:",largest)
# Out:
# largest number is: 500

# %% [markdown]
# numbers = [100, 200, 300, 400, 500]
# largest = numbers[0]
#
# for num in numbers:
#     if num > largest:
#         largest = num
#
# print("largest number is:", largest)

# %%
numbers = [100,200,300,400,500]
largest = numbers[0]
for num in numbers:
    if num > largest:
        largest = num

print("largest number is:", largest)
# Out:
# largest number is: 500

# %%
n = "manoj"
print(n[::-1])
# Out:
# jonam

# %%
# How to reverse the string
n = "This is AI"
li = n.split()
for i in range (len(li)):
  print(len(li))
  print(li[i][::-1],end = " ")
# Out:
# 3
# sihT 3
# si 3
# IA
