# %%
class BankAccount:
   def __init__(self,id:str,balance:float,email:str,Phonenumber:int):
      """intializer"""
      self.id:str =id
      self.balance:float =balance
      self.email:str =email
      self.Phonenumber =Phonenumber
